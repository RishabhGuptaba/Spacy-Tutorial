# %% [markdown]
# # Learn To Spacy

# %% [markdown]
# Installing the Library on Linux/ Unix
#
# sudo pip install spacy
#
# sudo pip install en

# %%
# Loading the package
import spacy

# %%
# Import the English class
from spacy.lang.en import English

# %%
# Create the nlp object
nlp = English()

# %%
# Process a text
doc = nlp("Hi guys this is spacy's tutorial.")

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for i in doc:
    print(i.text) # we can use simple 'i' instead of 'i.text', but for for good programing user 'i.text'
# Out:
# Hi
# guys
# this
# is
# spacy
# 's
# tutorial
# .

# %%
# Altrenative Approach :1 for genrtaing tokens

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Altrenative Approach :2 for genrtaing tokens

# %%
import spacy
nlp = spacy.load('en')

# %% [markdown]
# Basic terms for NLP:
# + Tokenization:	Segmenting text into words, punctuations marks etc.
# + Part-of-speech: (POS) Tagging	Assigning word types to tokens, like verb or noun.
# + Dependency Parsing:	Assigning syntactic dependency labels, describing the relations between individual tokens, like subject or object.
# + Lemmatization:	Assigning the base forms of words. For example, the lemma of "was" is "be", and the lemma of "rats" is "rat".
# + Named Entity Recognition (NER):	Labelling named "real-world" objects, like persons, companies or locations.
# + Similarity:	Comparing words, text spans and documents and how similar they are to each other.
# + Sentence Boundary Detection (SBD):	Finding and segmenting individual sentences.
# + Text Classification:	Assigning categories or labels to a whole document, or parts of a document.
# + Rule-based Matching:	Finding sequences of tokens based on their texts and linguistic annotations, similar to regular expressions.
# + Training:	Updating and improving a statistical model's predictions.
# + Serialization:	Saving objects to files or byte strings.

# %%
# Loading the package
import spacy
# load the English Module
nlp = spacy.load('en')

# %%
# text
mytext_1= """Hi guys this is spacy's tutorial."""

# %%
# Reading the text
# Process the text
# Create NLP object
doc_1  = nlp(mytext_1)

# %%
# Checkt the type of doc
type(doc_1)
# Out:
# spacy.tokens.doc.Doc

# %%
for words in doc_1:
        print(words.text)
# Out:
# Hi
# guys
# this
# is
# spacy
# 's
# tutorial
# .

# %%
# Comprehension
# List of tokens

[words.text for words in doc_1]
# Out:
# ['Hi', 'guys', 'this', 'is', 'spacy', "'s", 'tutorial', '.']

# %%
# Index
print(doc_1[1])
print(doc_1[-1])
print(doc_1[-2])
# Out:
# guys
# .
# tutorial

# %%
# Span
span_1 = doc_1[1:4]
print(span_1)
# Out:
# guys this is

# %%
# Reading the documnets 
Repblic_1 = open("Republic.txt").read()
print(Repblic_1)
# Out:
# Mohammad Barkat Aalam, 25, has alleged that he was attacked on his way home on Saturday night and also forced to chant ‘Jai Sri Ram and Bharat Mata Ki Jai.’ The attackers also allegedly threw his skull cap. According to the FIR registered in the matter, the men told the complainant that the cap was not allowed in the area
#
# Taking to Twitter, Gautam Gambhir said, “In Gurugram, Muslim man told to remove skullcap, chant Jai Shri Ram. It is deplorable. Exemplary action needed by Gurugram authorities. We are a secular nation where @Javedakhtarjadu writes “O Palan Haare, Nirgun aur Nyaare” and Rakeysh Om Mehra gave us the song “Arziyan” in Delhi 6.”
#
# Aalam alleged that there were four men on motorcycle and two on foot. “The men on foot beat me and said you cannot wear a cap in this area… They had both consumed alcohol. The four men on the motorcycle did not say anything to me… both men threatened to kill me.”
#
# He also alleged that he was forced to chant “Jai Shri Ram.” “I asked him why I needed to chant this, but the man became angry, grabbed a stick from the road, and hit me, while the other man encouraged him. When I tried to run away, they tore my kurta. I started crying and they ran away after that,” he further alleged.
#
# The sloganeering is, however, not included in the FIR. “I narrated the entire incident to police. I do not know what they included and what they left out; I was too afraid to ask.” Police have denied the allegations

# %%
# Create NLP Object
Doc_Republic_1= nlp(Repblic_1)

# %%
type(Doc_Republic_1)
# Out:
# spacy.tokens.doc.Doc

# %%
# Tokenization : Split the text in to tokens.
# Create Token
for words in Doc_Republic_1:
    print(words.text)
# Out:
# Mohammad
# Barkat
# Aalam
# ,
# 25
# ,
# has
# alleged
# that
# he
# was
# attacked
# on
# his
# way
# home
# on
# Saturday
# night
# and
# also
# forced
# to
# chant
# ‘
# Jai
# Sri
# Ram
# and
# Bharat
# Mata
# Ki
# Jai
# .
# ’
# The
# attackers
# also
# allegedly
# threw
# his
# skull
# cap
# .
# According
# to
# the
# FIR
# registered
# in
# the
# matter
# ,
# the
# men
# told
# the
# complainant
# that
# the
# cap
# was
# not
# allowed
# in
# the
# area
#
#
#
# Taking
# to
# Twitter
# ,
# Gautam
# Gambhir
# said
# ,
# “
# In
# Gurugram
# ,
# Muslim
# man
# told
# to
# remove
# skullcap
# ,
# chant
# Jai
# Shri
# Ram
# .
# It
# is
# deplorable
# .
# Exemplary
# action
# needed
# by
# Gurugram
# authorities
# .
# We
# are
# a
# secular
# nation
# where
# @Javedakhtarjadu
# writes
# “
# O
# Palan
# Haare
# ,
# Nirgun
# aur
# Nyaare
# ”
# and
# Rakeysh
# Om
# Mehra
# gave
# us
# the
# song
# “
# Arziyan
# ”
# in
# Delhi
# 6
# .
# ”
#
#
#
# Aalam
# alleged
# that
# there
# were
# four
# men
# on
# motorcycle
# and
# two
# on
# foot
# .
# “
# The
# men
# on
# foot
# beat
# me
# and
# said
# you
# can
# not
# wear
# a
# cap
# in
# this
# area
# …
# They
# had
# both
# consumed
# alcohol
# .
# The
# four
# men
# on
# the
# motorcycle
# did
# not
# say
# anything
# to
# me
# …
# both
# men
# threatened
# to
# kill
# me
# .
# ”
#
#
#
# He
# also
# alleged
# that
# he
# was
# forced
# to
# chant
# “
# Jai
# Shri
# Ram
# .
# ”
# “
# I
# asked
# him
# why
# I
# needed
# to
# chant
# this
# ,
# but
# the
# man
# became
# angry
# ,
# grabbed
# a
# stick
# from
# the
# road
# ,
# and
# hit
# me
# ,
# while
# the
# other
# man
# encouraged
# him
# .
# When
# I
# tried
# to
# run
# away
# ,
# they
# tore
# my
# kurta
# .
# I
# started
# crying
# and
# they
# ran
# away
# after
# that
# ,
# ”
# he
# further
# alleged
# .
#
#
#
# The
# sloganeering
# is
# ,
# however
# ,
# not
# included
# in
# the
# FIR
# .
# “
# I
# narrated
# the
# entire
# incident
# to
# police
# .
# I
# do
# not
# know
# what
# they
# included
# and
# what
# they
# left
# out
# ;
# I
# was
# too
# afraid
# to
# ask
# .
# ”
# Police
# have
# denied
# the
# allegations

# %%
# Tokenization: Break text in to te Sentences
for sentences in Doc_Republic_1.sents:
    print(sentences)
# Out:
# Mohammad Barkat Aalam, 25, has alleged that he was attacked on his way home on Saturday night and also forced to chant ‘
# Jai Sri Ram and Bharat Mata Ki Jai.
# ’
# The attackers also allegedly threw his skull cap.
# According to the FIR registered in the matter, the men told the complainant that the cap was not allowed in the area
#
# Taking to Twitter, Gautam Gambhir said, “
# In Gurugram, Muslim man told to remove skullcap, chant Jai Shri Ram.
# It is deplorable.
# Exemplary action needed by Gurugram authorities.
# We are a secular nation where @Javedakhtarjadu writes “O Palan Haare, Nirgun aur Nyaare” and
# Rakeysh Om Mehra gave us the song “Arziyan” in Delhi 6.
# ”
#
# Aalam alleged that there were four men on motorcycle and two on foot.
# “
# The men on foot beat me and said you cannot wear a cap in this area
# …
# They had both consumed alcohol.
# The four men on the motorcycle did not say anything to me
# …
# both men threatened to kill me.
# ”
#
#
# He also alleged that he was forced to chant “Jai Shri Ram.
# ”
# “
# I asked him why I needed to chant this, but the man became angry, grabbed a stick from the road, and hit me, while the other man encouraged him.
# When I tried to run away, they tore my kurta.
# I started crying and they ran away after that,” he further alleged.
#
#
# The sloganeering is, however, not included in the FIR.
# “
# I narrated the entire incident to police.
# I do not know what they included and what they left out; I was too afraid to ask.
# ”
# Police have denied the allegations

# %%
for num, sentences in enumerate(Doc_Republic_1.sents):
    print(f'{num}:{sentences}')
# Out:
# 0:Mohammad Barkat Aalam, 25, has alleged that he was attacked on his way home on Saturday night and also forced to chant ‘
# 1:Jai Sri Ram and Bharat Mata Ki Jai.
# 2:’
# 3:The attackers also allegedly threw his skull cap.
# 4:According to the FIR registered in the matter, the men told the complainant that the cap was not allowed in the area
#
# Taking to Twitter, Gautam Gambhir said, “
# 5:In Gurugram, Muslim man told to remove skullcap, chant Jai Shri Ram.
# 6:It is deplorable.
# 7:Exemplary action needed by Gurugram authorities.
# 8:We are a secular nation where @Javedakhtarjadu writes “O Palan Haare, Nirgun aur Nyaare” and
# 9:Rakeysh Om Mehra gave us the song “Arziyan” in Delhi 6.
# 10:”
#
# Aalam alleged that there were four men on motorcycle and two on foot.
# 11:“
# 12:The men on foot beat me and said you cannot wear a cap in this area
# 13:…
# 14:They had both consumed alcohol.
# 15:The four men on the motorcycle did not say anything to me
# 16:…
# 17:both men threatened to kill me.
# 18:”
#
#
# 19:He also alleged that he was forced to chant “Jai Shri Ram.
# 20:”
# 21:“
# 22:I asked him why I needed to chant this, but the man became angry, grabbed a stick from the road, and hit me, while the other man encouraged him.
# 23:When I tried to run away, they tore my kurta.
# 24:I started crying and they ran away after that,” he further alleged.
#
#
# 25:The sloganeering is, however, not included in the FIR.
# 26:“
# 27:I narrated the entire incident to police.
# 28:I do not know what they included and what they left out; I was too afraid to ask.
# 29:”
# 30:Police have denied the allegations

# %%
# Comprehension
[words.text for words in Doc_Republic_1]
# Out:
# ['Mohammad',
#  'Barkat',
#  'Aalam',
#  ',',
#  '25',
#  ',',
#  'has',
#  'alleged',
#  'that',
#  'he',
#  'was',
#  'attacked',
#  'on',
#  'his',
#  'way',
#  'home',
#  'on',
#  'Saturday',
#  'night',
#  'and',
#  'also',
#  'forced',
#  'to',
#  'chant',
#  '‘',
#  'Jai',
#  'Sri',
#  'Ram',
#  'and',
#  'Bharat',
#  'Mata',
#  'Ki',
#  'Jai',
#  '.',
#  '’',
#  'The',
#  'attackers',
#  'also',
#  'allegedly',
#  'threw',
#  'his',
#  'skull',
#  'cap',
#  '.',
#  'According',
#  'to',
#  'the',
#  'FIR',
#  'registered',
#  'in',
#  'the',
#  'matter',
#  ',',
#  'the',
#  'men',
#  'told',
#  'the',
#  'complainant',
#  'that',
#  'the',
#  'cap',
#  'was',
#  'not',
#  'allowed',
#  'in',
#  'the',
#  'area',
#  '\n\n',
#  'Taking',
#  'to',
#  'Twitter',
#  ',',
#  'Gautam',
#  'Gambhir',
#  'said',
#  ',',
#  '“',
#  'In',
#  'Gurugram',
#  ',',
#  'Muslim',
#  'man',
#  'told',
#  'to',
#  'remove',
#  'skullcap',
#  ',',
#  'chant',
#  'Jai',
#  'Shri',
#  'Ram',
#  '.',
#  'It',
#  'is',
#  'deplorable',
#  '.',
#  'Exemplary',
#  'action',
#  'needed',
#  'by',
#  'Gurugram',
#  'authorities',
#  '.',
#  'We',
#  'are',
#  'a',
#  'secular',
#  'nation',
#  'where',
#  '@Javedakhtarjadu',
#  'writes',
#  '“',
#  'O',
#  'Palan',
#  'Haare',
#  ',',
#  'Nirgun',
#  'aur',
#  'Nyaare',
#  '”',
#  'and',
#  'Rakeysh',
#  'Om',
#  'Mehra',
#  'gave',
#  'us',
#  'the',
#  'song',
#  '“',
#  'Arziyan',
#  '”',
#  'in',
#  'Delhi',
#  '6',
#  '.',
#  '”',
#  '\n\n',
#  'Aalam',
#  'alleged',
#  'that',
#  'there',
#  'were',
#  'four',
#  'men',
#  'on',
#  'motorcycle',
#  'and',
#  'two',
#  'on',
#  'foot',
#  '.',
#  '“',
#  'The',
#  'men',
#  'on',
#  'foot',
#  'beat',
#  'me',
#  'and',
#  'said',
#  'you',
#  'can',
#  'not',
#  'wear',
#  'a',
#  'cap',
#  'in',
#  'this',
#  'area',
#  '…',
#  'They',
#  'had',
#  'both',
#  'consumed',
#  'alcohol',
#  '.',
#  'The',
#  'four',
#  'men',
#  'on',
#  'the',
#  'motorcycle',
#  'did',
#  'not',
#  'say',
#  'anything',
#  'to',
#  'me',
#  '…',
#  'both',
#  'men',
#  'threatened',
#  'to',
#  'kill',
#  'me',
#  '.',
#  '”',
#  '\n\n',
#  'He',
#  'also',
#  'alleged',
#  'that',
#  'he',
#  'was',
#  'forced',
#  'to',
#  'chant',
#  '“',
#  'Jai',
#  'Shri',
#  'Ram',
#  '.',
#  '”',
#  '“',
#  'I',
#  'asked',
#  'him',
#  'why',
#  'I',
#  'needed',
#  'to',
#  'chant',
#  'this',
#  ',',
#  'but',
#  'the',
#  'man',
#  'became',
#  'angry',
#  ',',
#  'grabbed',
#  'a',
#  'stick',
#  'from',
#  'the',
#  'road',
#  ',',
#  'and',
#  'hit',
#  'me',
#  ',',
#  'while',
#  'the',
#  'other',
#  'man',
#  'encouraged',
#  'him',
#  '.',
#  'When',
#  'I',
#  'tried',
#  'to',
#  'run',
#  'away',
#  ',',
#  'they',
#  'tore',
#  'my',
#  'kurta',
#  '.',
#  'I',
#  'started',
#  'crying',
#  'and',
#  'they',
#  'ran',
#  'away',
#  'after',
#  'that',
#  ',',
#  '”',
#  'he',
#  'further',
#  'alleged',
#  '.',
#  '\n\n',
#  'The',
#  'sloganeering',
#  'is',
#  ',',
#  'however',
#  ',',
#  'not',
#  'included',
#  'in',
#  'the',
#  'FIR',
#  '.',
#  '“',
#  'I',
#  'narrated',
#  'the',
#  'entire',
#  'incident',
#  'to',
#  'police',
#  '.',
#  'I',
#  'do',
#  'not',
#  'know',
#  'what',
#  'they',
#  'included',
#  'and',
#  'what',
#  'they',
#  'left',
#  'out',
#  ';',
#  'I',
#  'was',
#  'too',
#  'afraid',
#  'to',
#  'ask',
#  '.',
#  '”',
#  'Police',
#  'have',
#  'denied',
#  'the',
#  'allegations',
#  '\n\n\n']

# %%
doc = nlp("Hi guys this is spacy's tutorial.")
print('Index:   ', [token.i for token in doc])
print('Text:    ', [token.text for token in doc])

print('is_alpha:', [token.is_alpha for token in doc])
print('is_punct:', [token.is_punct for token in doc])
print('like_num:', [token.like_num for token in doc])
# Out:
# Index:    [0, 1, 2, 3, 4, 5, 6, 7]
# Text:     ['Hi', 'guys', 'this', 'is', 'spacy', "'s", 'tutorial', '.']
# is_alpha: [True, True, True, True, True, False, True, False]
# is_punct: [False, False, False, False, False, False, False, True]
# like_num: [False, False, False, False, False, False, False, False]

# %% [markdown]
# ### More about words
# + .shape_ ==> for shape of word eg. capital,lowercase,etc
# + .is_alpha ==> returns boolean(true or false) if word is alphabet
# + .is_stop ==> returns boolean(true or false) if word is a stop word

# %%
for words in doc:
    print(words.text,words.shape_)
# Out:
# Hi Xx
# guys xxxx
# this xxxx
# is xx
# spacy xxxx
# 's 'x
# tutorial xxxx
# . .

# %%
for words in doc:
    print(words.text,words.is_alpha)
# Out:
# Hi True
# guys True
# this True
# is True
# spacy True
# 's False
# tutorial True
# . False

# %%
# check the stop words in the documnets / text
for words in doc:
    print(words.text,words.is_stop)
# Out:
# Hi False
# guys False
# this True
# is True
# spacy False
# 's True
# tutorial False
# . False

# %%
# which tokens are number
for words in doc:
    print(words.text,words.like_num)
# Out:
# Hi False
# guys False
# this False
# is False
# spacy False
# 's False
# tutorial False
# . False

# %%
for words in doc:
    print('{:<12}{:<10}{:<10}'.format(words.text, words.is_stop,words.like_num))
# Out:
# Hi          0         0
# guys        0         0
# this        1         0
# is          1         0
# spacy       0         0
# 's          1         0
# tutorial    0         0
# .           0         0

# %% [markdown]
# # Data Structures:
# + Vocab

# %% [markdown]
# Spacy stored all data in vocab, it work like as Hash function, we don't need to store value again and again.
# - Please see the given below example

# %%
doc = nlp("this is spacy's tutorial|")
ST = nlp.vocab['spacy']

print(ST.text, ST.orth, ST.is_alpha)
# Out:
# spacy 10639093010105930009 True

# %% [markdown]
# # Creating a DOC
#
# - Doc's created automatically when we process any text data with nlp object. But here we are creating Doc manually by importing Doc

# %%
# Import the Doc class
from spacy.tokens import Doc

# The words and spaces to create the doc from
words = ['This', 'is', 'spacy', 'tutorial','!']
spaces = [True, True, True,False,True]  # True = Space
                                        # False = Not Space

# Create a doc manually
doc = Doc(nlp.vocab, words=words, spaces=spaces)

print(doc)
# Out:
# This is spacy tutorial!

# %% [markdown]
# # Span
#
# - Span is a slice of a Doc, which consist one or more tokens.
# - The Span must have at least 3 arguments.

# %% [markdown]
# ![the%20span.png](attachment:the%20span.png)

# %%
from spacy.tokens import Doc, Span
# Create a span manually
span = Span(doc, 0, 2)

print(span)
# Out:
# This is

# %%
# Create a span with a label
span_with_label = Span(doc, 0, 2, label="kuchbhi")

# Add span to the doc.ents
doc.ents = [span_with_label]

# %%
for i in doc.ents:
    print(i.label_)
# Out:
# kuchbhi

# %% [markdown]
# # Statistical models

# %% [markdown]
# ### Part of Speech Tagging
# +  NB attribute_ ==> Returns readable string representation of attribute
# + .pos
# + .pos_ ==> exposes Google Universal pos_tag,simple
# + .tag
# + .tag_ ==> exposes Treebank, detailed,for training your own model
# + + Uses
# - - Sentiment Analysis,Homonym Disambuguity ,Prediction

# %%
mytext_2 = """Delhi is a very beutiful state"""

# %%
doc_2 = nlp(mytext_2)

# %%
for i in doc_2:
    print(i.text,i.pos_)
# Out:
# Delhi PROPN
# is VERB
# a DET
# very ADV
# beutiful ADJ
# state NOUN

# %%
# spacy help
spacy.explain('ADV')
# Out:
# 'adverb'

# %% [markdown]
# #### Syntactic Dependency
# + It helps us to know the relation between tokens
# + How each word is connected and dependent on each other

# %%
doc_4 = nlp("Hi guys this is spacy's tutorial.")

# %%
for words in doc_4:
    print(words.text,words.pos_,words.dep_)
# Out:
# Hi INTJ intj
# guys NOUN nsubj
# this DET nsubj
# is VERB ROOT
# spacy NOUN poss
# 's PART case
# tutorial NOUN attr
# . PUNCT punct

# %%
for words in doc_4:
    print((words.text,words.pos_,words.dep_))
# Out:
# ('Hi', 'INTJ', 'intj')
# ('guys', 'NOUN', 'nsubj')
# ('this', 'DET', 'nsubj')
# ('is', 'VERB', 'ROOT')
# ('spacy', 'NOUN', 'poss')
# ("'s", 'PART', 'case')
# ('tutorial', 'NOUN', 'attr')
# ('.', 'PUNCT', 'punct')

# %%
spacy.explain('attr')
# Out:
# 'attribute'

# %% [markdown]
# ### Visualizing Dependency using displaCy
# + from spacy import displacy
# + displacy.serve() for server  or for local machine server
# + displacy.render(jupyter=True) # for jupyter notebook

# %%
from spacy import displacy

# %%
# .render only for jupyter notebook

displacy.render(doc_4,style="dep",jupyter = True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f150d4a994144fadbfde8b5da401095c-0" class="displacy" width="1275" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Hi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">guys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">spacy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">tutorial.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-1" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-3" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,266.5 L762,254.5 778,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f150d4a994144fadbfde8b5da401095c-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f150d4a994144fadbfde8b5da401095c-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
# </svg>

# %% [markdown]
# # Lemmatization
# # .lemma_

# %% [markdown]
#  ### Text Normalization  and Word Inflection
# + Word inflection == syntactic differences between word forms
# + Reducing a word to its base/root form
# + Lemmatization **
# - - a word based on its intended meaning
# + Stemming
# - - Cutting of the prefixes/suffices to reduce a word to base form
# + Word Shape Analysis

# %%
# Lemmatization
import spacy
nlp = spacy.load('en')

# %%
mytext_5 = "study syudying syudious studio student read reading go went gone"

# %%
doc_5 = nlp(mytext_5)

# %%
for words in doc_5:
    print(words.text,words.lemma_,words.pos_)
# Out:
# study study VERB
# syudying syudye VERB
# syudious syudious ADJ
# studio studio NOUN
# student student NOUN
# read read VERB
# reading read VERB
# go go VERB
# went go VERB
# gone go VERB

# %% [markdown]
# ### Named Entity Recognition or Detection
# ### .label_
#
# +  Classifying a text into predefined categories or real world object  entities.
# + takes a string of text (sentence or paragraph) as input and identifies relevant nouns (people, places, and organizations) that are mentioned in that string.
#
# ##### Uses
# + Classifying or Categorizing contents by getting the relevant tags
# + Improve search algorithms
# + For content recommendations
# + For info extraction
#
# + .ents
# + .label_

# %%
mytext_6 = """Talks between Etihad Airways, the Hinduja Group and AdiGro Aviation to revive Jet Airways have entered a crucial phase, with the three sides talking about operational role and representation on the board of the Indian airline.

Sources say that the banks, led by State Bank of India, are now "more flexible" while restructuring Jet Airways' debts of over Rs 8,000 crore. This will help bringing in the investors.

"The talks should be over by the end of the month, and the binding agreements should be in place by June," said a source close the development.

"""

# %%
doc_6= nlp(mytext_6)

# %%
for words in doc_6.ents:
    print(words.text,words.label_)
# Out:
# Etihad Airways ORG
# the Hinduja Group ORG
# AdiGro Aviation ORG
# Jet Airways ORG
# three CARDINAL
# Indian NORP
# State Bank of India ORG
# Jet Airways' ORG
# 8,000 crore MONEY
# the end of the month DATE
# June DATE

# %%
spacy.explain('NORP')
# Out:
# 'Nationalities or religious or political groups'

# %% [markdown]
# # Visualizing Entity using displaCy

# %%
from spacy import displacy

# %%
displacy.render(doc_6,style="ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Talks between
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Etihad Airways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the Hinduja Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     AdiGro Aviation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to revive
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jet Airways
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have entered a crucial phase, with the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  sides talking about operational role and representation on the board of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Indian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  airline.</br></br>Sources say that the banks, led by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     State Bank of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , are now &quot;more flexible&quot; while restructuring
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jet Airways'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  debts of over Rs
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     8,000 crore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . This will help bringing in the investors.</br></br>&quot;The talks should be over by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the end of the month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and the binding agreements should be in place by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,&quot; said a source close the development.
#
# </div>

# %% [markdown]
# #  Visualizing using displaCy

# %%
mytext_7 = """Talks between Etihad Airways, the Hinduja Group and AdiGro Aviation to revive Jet Airways have entered a crucial phase, with the three sides talking about operational role and representation on the board of the Indian airline.

Sources say that the banks, led by State Bank of India, are now "more flexible" while restructuring Jet Airways' debts of over Rs 8,000 crore. This will help bringing in the investors.

"The talks should be over by the end of the month, and the binding agreements should be in place by June," said a source close the development.

"""

# %%
doc_7 = nlp(mytext_7)

# %%
displacy.render(doc_7, style = 'dep',jupyter = True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8d5e340c69bd41778f313904a3067e81-0" class="displacy" width="17200" height="1362.0" direction="ltr" style="max-width: none; height: 1362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Talks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Etihad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Airways,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Hinduja</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Group</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">AdiGro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Aviation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">revive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Jet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Airways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">entered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">crucial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">phase,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">sides</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">talking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">operational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">role</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">representation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1272.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">the</tspan>
#     <tspan class="displacy-t

# %%
## Customizing the Diplays
# Compact set it to square arrows or curved arrows
# Color:#09a3d5
options = {'compact': True, 'bg': 'cornflowerblue',
           'color': '#fff', 'font': 'Sans Serif'}

# %%
displacy.render(doc_7,style ='dep',options = options,jupyter = True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0e7d08beb3554a3c91c458b81f3253f6-0" class="displacy" width="14750" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #fff; background: cornflowerblue; font-family: Sans Serif; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Talks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">between</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Etihad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Airways,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">Hinduja</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Group</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">AdiGro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Aviation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">revive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Jet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">Airways</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">entered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">crucial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">phase,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">sides</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">talking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">operational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">role</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">representation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">the</tspan>
#     <tspan class="dis

# %% [markdown]
# # Similarity
# - It is about Semantic Similarity, not syntax Similarity.
# - It works on w2v
# ### Semantic Similarity
# + object1.similarity(object2)
# + Uses:
# + - Recommendation systems
# + - Data Preprocessing eg removing duplicates

# %%
mytext_8 ="this is car made of steel"
mytext_9 = "this is car made of paper"

# %%
doc_8 = nlp(mytext_8)
doc_9 = nlp(mytext_9)

# %%
doc_8.similarity(doc_9)
# Out:
# 0.9262705999680061

# %% [markdown]
# - high value means more simlar , less value means low simlar.

# %%
for word_1 in doc_8:
    for word_2 in doc_9:
        print((word_1.text,word_2.text),word_1.similarity(word_2))
# Out:
# ('this', 'this') 1.0
# ('this', 'is') 0.5970357
# ('this', 'car') 0.29220003
# ('this', 'made') 0.54150325
# ('this', 'of') 0.4548816
# ('this', 'paper') 0.3074143
# ('is', 'this') 0.5970357
# ('is', 'is') 1.0
# ('is', 'car') 0.31487948
# ('is', 'made') 0.5000269
# ('is', 'of') 0.47661057
# ('is', 'paper') 0.2438742
# ('car', 'this') 0.29220003
# ('car', 'is') 0.31487948
# ('car', 'car') 1.0
# ('car', 'made') 0.29800084
# ('car', 'of') 0.26567426
# ('car', 'paper') 0.21048649
# ('made', 'this') 0.54150325
# ('made', 'is') 0.5000269
# ('made', 'car') 0.29800084
# ('made', 'made') 1.0
# ('made', 'of') 0.48947448
# ('made', 'paper') 0.39457515
# ('of', 'this') 0.4548816
# ('of', 'is') 0.47661057
# ('of', 'car') 0.26567426
# ('of', 'made') 0.48947448
# ('of', 'of') 1.0
# ('of', 'paper') 0.33912402
# ('steel', 'this') 0.16393036
# ('steel', 'is') 0.19674529
# ('steel', 'car') 0.21784334
# ('steel', 'made') 0.35369274
# ('steel', 'of') 0.18653294
# ('steel', 'paper') 0.24732819

# %%
# comprehension
mylist =[(word_1.text,word_2.text,word_1.similarity(word_2))for word_1 in doc_8 for word_2 in doc_9]

# %%
mylist
# Out:
# [('this', 'this', 1.0),
#  ('this', 'is', 0.5970357),
#  ('this', 'car', 0.29220003),
#  ('this', 'made', 0.54150325),
#  ('this', 'of', 0.4548816),
#  ('this', 'paper', 0.3074143),
#  ('is', 'this', 0.5970357),
#  ('is', 'is', 1.0),
#  ('is', 'car', 0.31487948),
#  ('is', 'made', 0.5000269),
#  ('is', 'of', 0.47661057),
#  ('is', 'paper', 0.2438742),
#  ('car', 'this', 0.29220003),
#  ('car', 'is', 0.31487948),
#  ('car', 'car', 1.0),
#  ('car', 'made', 0.29800084),
#  ('car', 'of', 0.26567426),
#  ('car', 'paper', 0.21048649),
#  ('made', 'this', 0.54150325),
#  ('made', 'is', 0.5000269),
#  ('made', 'car', 0.29800084),
#  ('made', 'made', 1.0),
#  ('made', 'of', 0.48947448),
#  ('made', 'paper', 0.39457515),
#  ('of', 'this', 0.4548816),
#  ('of', 'is', 0.47661057),
#  ('of', 'car', 0.26567426),
#  ('of', 'made', 0.48947448),
#  ('of', 'of', 1.0),
#  ('of', 'paper', 0.33912402),
#  ('steel', 'this', 0.16393036),
#  ('steel', 'is', 0.19674529),
#  ('steel', 'car', 0.21784334),
#  ('steel', 'made', 0.35369274),
#  ('steel', 'of', 0.18653294),
#  ('steel', 'paper', 0.24732819)]

# %%
# convert list in to data frame
import pandas as pd
df = pd.DataFrame(mylist)

# %%
df
# Out:
#         0      1         2
# 0    this   this  1.000000
# 1    this     is  0.597036
# 2    this    car  0.292200
# 3    this   made  0.541503
# 4    this     of  0.454882
# 5    this  paper  0.307414
# 6      is   this  0.597036
# 7      is     is  1.000000
# 8      is    car  0.314879
# 9      is   made  0.500027
# 10     is     of  0.476611
# 11     is  paper  0.243874
# 12    car   this  0.292200
# 13    car     is  0.314879
# 14    car    car  1.000000
# 15    car   made  0.298001
# 16    car     of  0.265674
# 17    car  paper  0.210486
# 18   made   this  0.541503
# 19   made     is  0.500027
# 20   made    car  0.298001
# 21   made   made  1.000000
# 22   made     of  0.489474
# 23   made  paper  0.394575
# 24     of   this  0.454882
# 25     of     is  0.476611
# 26     of    car  0.265674
# 27     of   made  0.489474
# 28     of     of  1.000000
# 29     of  paper  0.339124
# 30  steel   this  0.163930
# 31  steel     is  0.196745
# 32  steel    car  0.217843
# 33  steel   made  0.353693
# 34  steel     of  0.186533
# 35  steel  paper  0.247328

# %%
df.columns = ["Word_1","Word_2","Similarity"]

# %%
df['Word_1'].unique()
# Out:
# array(['this', 'is', 'car', 'made', 'of', 'steel'], dtype=object)

# %%
df['Word_2'].unique()
# Out:
# array(['this', 'is', 'car', 'made', 'of', 'paper'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_new = df.replace({'this':0, 'is':1, 'car':2, 'made':3, 'of':4, 'paper':5,'steel':6})

# %%
df_new
# Out:
#     Word_1  Word_2  Similarity
# 0        0       0    1.000000
# 1        0       1    0.597036
# 2        0       2    0.292200
# 3        0       3    0.541503
# 4        0       4    0.454882
# 5        0       5    0.307414
# 6        1       0    0.597036
# 7        1       1    1.000000
# 8        1       2    0.314879
# 9        1       3    0.500027
# 10       1       4    0.476611
# 11       1       5    0.243874
# 12       2       0    0.292200
# 13       2       1    0.314879
# 14       2       2    1.000000
# 15       2       3    0.298001
# 16       2       4    0.265674
# 17       2       5    0.210486
# 18       3       0    0.541503
# 19       3       1    0.500027
# 20       3       2    0.298001
# 21       3       3    1.000000
# 22       3       4    0.489474
# 23       3       5    0.394575
# 24       4       0    0.454882
# 25       4       1    0.476611
# 26       4       2    0.265674
# 27       4       3    0.489474
# 28       4       4    1.000000
# 29       4       5    0.339124
# 30       6       0    0.163930
# 31       6       1    0.196745
# 32       6       2    0.217843
# 33       6       3    0.353693
# 34       6       4    0.186533
# 35       6       5    0.247328

# %%
# correlation plot
plt.figure(figsize=(20,10))
sns.heatmap(df_new.corr(),annot= True)
plt.show()

# %%
# correlation plot
plt.figure(figsize=(20,10))
sns.heatmap(df_new,annot= True)
plt.show()

# %% [markdown]
# # create vectors of the words (w2v)

# %%
import spacy

# Load the en_core_web_md model
nlp = spacy.load("en_core_web_sm")

# for medium model: en_core_web_md 
# for large model: en_core_web_lg 

# Process a text
doc = nlp("this is spacy tutorial")

# Get the vector for the token "bananas"
word_vector = doc[1].vector
print(word_vector)
# Out:
# [-2.1616883  -0.83719236  4.336971    2.0881162   2.1307774  -0.01830411
#   3.6556325   0.6140834   6.0727577  -1.8409129  -1.5433214   2.211865
#  -3.2634592   2.5222602  -1.596766   -2.106433   -5.094246    1.4519442
#  -0.5948645  -2.9426522  -2.9272044   3.1295156   2.3910244   1.793421
#   3.397977    1.0471468   1.4283283  -4.1532555   1.7703824  -0.2641956
#   0.92888534 -0.97977144  0.649572    0.6694351   2.5225573   0.50951046
#  -3.1752043   1.3732395  -6.735564    2.7235599  -0.7247958   0.05628073
#   3.8728418   2.1695936   3.2828372   0.38164175  2.3044121   0.74997544
#  -3.0787587   1.3705323  -2.3586998  -1.854167   -2.2662458   0.57641643
#   4.0864577  -1.6989623   1.6326907   4.511441   -4.768631    2.3158672
#  -3.8809693   0.78832597  0.45046046  2.3127286   2.0678387   6.2467723
#  -3.8207035  -0.7542125  -2.6011996  -2.3489637   2.482747   -0.72221786
#   0.76522946  0.97648835 -0.22268239  1.552115   -0.82804    -5.212626
#  -1.2038113  -0.6549634   0.4084021  -1.8696872   3.2658703  -2.1123834
#   0.07449281 -0.36246955 -2.1735258  -2.337294    1.2812082  -1.7655412
#   2.317006   -0.20730424 -4.701669    1.9304278  -3.8874655  -1.7519709 ]

# %% [markdown]
# # Stop Words
# # Removing, Adding and Checking

# %% [markdown]
# ### Stops Words In Spacy
# + A Stop word/Stop list
# + Words filtered out before preprocessing
# + Most Common words*
#
# #### Uses
# + Improve performance in search engines
# + + eg how to perform sentiment analysis
# + Eliminating noise and distraction in sentiment classification
# + + Make ML learning faster due to less features
# + + Make Prediction more accurate due to noise reduction

# %%
import spacy
nlp = spacy.load('en')

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'same', 'hereby', '‘s', 'made', 'whom', 'his', 'itself', 'that', 'give', '’m', 'together', 'must', '‘m', 'nothing', 'among', 'around', 'twelve', 'even', 'yourselves', 'therein', 'over', 'after', 'those', 'before', 'somehow', 'whereby', 'seeming', 'some', 'seems', 'call', 'had', 'still', 'thru', 'latterly', 'upon', 'an', 'the', 'did', 'put', 'both', '‘d', 'either', 'of', 'sixty', 'should', "'ve", 'one', 'you', 'mine', 'per', 'whence', 'becoming', "'s", 'afterwards', 'where', 'wherever', 'do', 'nor', 'due', 'elsewhere', 'n‘t', 'anywhere', 'become', 'only', 'sometime', 'are', 'anything', 'between', 'beforehand', 'himself', 'is', 'always', 'would', 'then', 'quite', 'five', 'ten', 'herein', 'mostly', 'or', 'behind', 'via', 'for', 'her', 'moreover', 'ourselves', 'thereupon', 'whether', 'many', 'during', 'move', 'someone', 'thence', 'third', 'six', 'every', 'wherein', 'under', 'out', 'four', 'may', 'whole', 'being', 'front', 'yourself', 'toward', 'hundred', 'herself', 'various', 'became', 'seem', 'perhaps', 'be', 'thus', "'re", 'we', '‘ll', 'him', 'noone', 'more', 'few', 'whereupon', 'keep', 'this', 'again', 'with', 'your', 'from', 'amongst', 'along', 'any', 'show', 'whereas', 'themselves', 'why', 'a', 'myself', 'therefore', 'beside', 'besides', 'than', 'twenty', 'has', 'who', 'nine', 'our', 'but', 'latter', 'down', 'anyone', 'off', 'he', 'at', 'none', 'all', 'something', '’d', 'cannot', 'except', 'up', 'several', 'been', 'least', 'whatever', 'towards', 'somewhere', 'everywhere', 'everyone', 'take', 'since', 'almost', 'hereafter', 'unless', 'have', 'eleven', 'my', 'what', 'which', 'back', 'next', 'becomes', 'own', 'meanwhile', 'much', 'yours', 'other', 'doing', 'seemed', 'will', 'above', 'done', 'otherwise', 'using', 'part', 'by', 'now', 'until', 'forty', 'however', 'its', 'others', 'empty', 'though', 'without', '’ve', 'when', 'thereafter', 'in', 'namely', 'each', 'rather', 'also', 'enough', 'fifteen', 'no', 'alone', 'through', 'as', 'how', 'formerly', 'really', 'nobody', 'across', 'them', 'whoever', "'m", 'just', 'below', 'last', 'about', 'please', 'these', 'serious', 'go', 'whither', "'ll", 'indeed', 'such', 'hers', 'former', 'their', 'eight', 'very', 'might', 'two', 'used', 'it', 'hence', '‘ve', 'hereupon', 'everything', 'ever', 'beyond', 'fifty', 'does', 'once', 'three', 'whose', 'full', 'am', 'me', 'to', 'neither', 'anyhow', 'bottom', 'although', 'top', 'was', 'see', 'whenever', '’ll', 'throughout', 'she', 'whereafter', 'make', '’s', 'side', 'say', 'on', '‘re', 'first', 'anyway', 'here', 'while', 'regarding', 'else', 'can', 'get', 'amount', 'often', 'name', "n't", 'and', 'ca', '’re', 'further', 'there', 'not', 'already', 'never', 'because', 'sometimes', 'i', 'nowhere', 'too', 'well', 'so', 'thereby', 'yet', 'us', 're', 'ours', 'nevertheless', 'into', 'against', 'could', 'were', 'within', 'another', 'onto', 'most', 'if', 'less', "'d", 'n’t', 'they'}

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
# Check whether word is stop words or not

nlp.vocab["the"].is_stop
# Out:
# True

# %%
doc_10 = open("Republic.txt").read()

# %%
Republic_10 = nlp(doc_10)

# %%
# Filterout the stop words
for words in Republic_10:
    if words.is_stop == True:
        print(words)
# Out:
# has
# that
# he
# was
# on
# his
# on
# and
# also
# to
# and
# The
# also
# his
# to
# the
# in
# the
# the
# the
# that
# the
# was
# not
# in
# the
# to
# In
# to
# It
# is
# by
# We
# are
# a
# where
# and
# us
# the
# in
# that
# there
# were
# four
# on
# and
# two
# on
# The
# on
# me
# and
# you
# can
# not
# a
# in
# this
# They
# had
# both
# The
# four
# on
# the
# did
# not
# say
# anything
# to
# me
# both
# to
# me
# He
# also
# that
# he
# was
# to
# I
# him
# why
# I
# to
# this
# but
# the
# became
# a
# from
# the
# and
# me
# while
# the
# other
# him
# When
# I
# to
# they
# my
# I
# and
# they
# after
# that
# he
# further
# The
# is
# however
# not
# in
# the
# I
# the
# to
# I
# do
# not
# what
# they
# and
# what
# they
# out
# I
# was
# too
# to
# have
# the

# %%
# filter out non stop words
for words in Republic_10:
    if words.is_stop == False:
        print(words)
# Out:
# Mohammad
# Barkat
# Aalam
# ,
# 25
# ,
# alleged
# attacked
# way
# home
# Saturday
# night
# forced
# chant
# ‘
# Jai
# Sri
# Ram
# Bharat
# Mata
# Ki
# Jai
# .
# ’
# attackers
# allegedly
# threw
# skull
# cap
# .
# According
# FIR
# registered
# matter
# ,
# men
# told
# complainant
# cap
# allowed
# area
#
#
#
# Taking
# Twitter
# ,
# Gautam
# Gambhir
# said
# ,
# “
# Gurugram
# ,
# Muslim
# man
# told
# remove
# skullcap
# ,
# chant
# Jai
# Shri
# Ram
# .
# deplorable
# .
# Exemplary
# action
# needed
# Gurugram
# authorities
# .
# secular
# nation
# @Javedakhtarjadu
# writes
# “
# O
# Palan
# Haare
# ,
# Nirgun
# aur
# Nyaare
# ”
# Rakeysh
# Om
# Mehra
# gave
# song
# “
# Arziyan
# ”
# Delhi
# 6
# .
# ”
#
#
#
# Aalam
# alleged
# men
# motorcycle
# foot
# .
# “
# men
# foot
# beat
# said
# wear
# cap
# area
# …
# consumed
# alcohol
# .
# men
# motorcycle
# …
# men
# threatened
# kill
# .
# ”
#
#
#
# alleged
# forced
# chant
# “
# Jai
# Shri
# Ram
# .
# ”
# “
# asked
# needed
# chant
# ,
# man
# angry
# ,
# grabbed
# stick
# road
# ,
# hit
# ,
# man
# encouraged
# .
# tried
# run
# away
# ,
# tore
# kurta
# .
# started
# crying
# ran
# away
# ,
# ”
# alleged
# .
#
#
#
# sloganeering
# ,
# ,
# included
# FIR
# .
# “
# narrated
# entire
# incident
# police
# .
# know
# included
# left
# ;
# afraid
# ask
# .
# ”
# Police
# denied
# allegations

# %%
[words for words in Republic_10 if words.is_stop== False]
# Out:
# [Mohammad,
#  Barkat,
#  Aalam,
#  ,,
#  25,
#  ,,
#  alleged,
#  attacked,
#  way,
#  home,
#  Saturday,
#  night,
#  forced,
#  chant,
#  ‘,
#  Jai,
#  Sri,
#  Ram,
#  Bharat,
#  Mata,
#  Ki,
#  Jai,
#  .,
#  ’,
#  attackers,
#  allegedly,
#  threw,
#  skull,
#  cap,
#  .,
#  According,
#  FIR,
#  registered,
#  matter,
#  ,,
#  men,
#  told,
#  complainant,
#  cap,
#  allowed,
#  area,
#
#  ,
#  Taking,
#  Twitter,
#  ,,
#  Gautam,
#  Gambhir,
#  said,
#  ,,
#  “,
#  Gurugram,
#  ,,
#  Muslim,
#  man,
#  told,
#  remove,
#  skullcap,
#  ,,
#  chant,
#  Jai,
#  Shri,
#  Ram,
#  .,
#  deplorable,
#  .,
#  Exemplary,
#  action,
#  needed,
#  Gurugram,
#  authorities,
#  .,
#  secular,
#  nation,
#  @Javedakhtarjadu,
#  writes,
#  “,
#  O,
#  Palan,
#  Haare,
#  ,,
#  Nirgun,
#  aur,
#  Nyaare,
#  ”,
#  Rakeysh,
#  Om,
#  Mehra,
#  gave,
#  song,
#  “,
#  Arziyan,
#  ”,
#  Delhi,
#  6,
#  .,
#  ”,
#
#  ,
#  Aalam,
#  alleged,
#  men,
#  motorcycle,
#  foot,
#  .,
#  “,
#  men,
#  foot,
#  beat,
#  said,
#  wear,
#  cap,
#  area,
#  …,
#  consumed,
#  alcohol,
#  .,
#  men,
#  motorcycle,
#  …,
#  men,
#  threatened,
#  kill,
#  .,
#  ”,
#
#  ,
#  alleged,
#  forced,
#  chant,
#  “,
#  Jai,
#  Shri,
#  Ram,
#  .,
#  ”,
#  “,
#  asked,
#  needed,
#  chant,
#  ,,
#  man,
#  angry,
#  ,,
#  grabbed,
#  stick,
#  road,
#  ,,
#  hit,
#  ,,
#  man,
#  encouraged,
#  .,
#  tried,
#  run,
#  away,
#  ,,
#  tore,
#  kurta,
#  .,
#  started,
#  crying,
#  ran,
#  away,
#  ,,
#  ”,
#  alleged,
#  .,
#
#  ,
#  sloganeering,
#  ,,
#  ,,
#  included,
#  FIR,
#  .,
#  “,
#  narrated,
#  entire,
#  incident,
#  police,
#  .,
#  know,
#  included,
#  left,
#  ;,
#  afraid,
#  ask,
#  .,
#  ”,
#  Police,
#  denied,
#  allegations,
#
#
#  ]

# %%
# Adding own stop words

STOP_WORDS.add("Rishabh")

# %%
# check wether stop words has added or not
nlp.vocab["Rishabh"].is_stop
# Out:
# False

# %%
# Remove the stop words

STOP_WORDS.remove("Rishabh")

# %%
# check wether stop words has delted or not
# False = means deleted

nlp.vocab["Rishabh"].is_stop
# Out:
# False

# %% [markdown]
# #### Noun Chunks
# + noun + word describing the noun
# + noun phrases
# + adnominal
# + root.text

# %%
for word in Republic_10.noun_chunks:
    print(word.text)
# Out:
# Mohammad Barkat Aalam
# he
# his way
# Saturday night
# Jai Sri Ram
# Bharat Mata Ki Jai
# The attackers
# his skull cap
# the FIR
# the matter
# the men
# the complainant
# the cap
# the area
# Twitter
# Gautam Gambhir
# Gurugram
# Muslim man
# skullcap
# Jai Shri Ram
# It
# Exemplary action
# Gurugram authorities
# We
# a secular nation
# @Javedakhtarjadu
# O Palan Haare
# Nirgun aur Nyaare
# Rakeysh Om Mehra
# us
# the song
# Delhi
# ”
#
# Aalam
# four men
# motorcycle
# foot
# The men
# foot
# me
# you
# a cap
# this area
# They
# alcohol
# The four men
# the motorcycle
# anything
# me
# both men
# me
# He
# he
# Jai Shri Ram
# I
# him
# I
# the man
# a stick
# the road
# me
# the other man
# him
# I
# they
# my kurta
# I
# they
# he
# The sloganeering
# the FIR
# I
# the entire incident
# police
# I
# what
# they
# what
# they
# I
# Police
# the allegations

# %%
# Root Text
# the Main Noun 
for word in Republic_10.noun_chunks:
    print(word.root.text)
# Out:
# Aalam
# he
# way
# night
# Ram
# Jai
# attackers
# cap
# FIR
# matter
# men
# complainant
# cap
# area
# Twitter
# Gambhir
# Gurugram
# man
# skullcap
# Ram
# It
# action
# authorities
# We
# nation
# @Javedakhtarjadu
# Haare
# Nyaare
# Mehra
# us
# song
# Delhi
# Aalam
# men
# motorcycle
# foot
# men
# foot
# me
# you
# cap
# area
# They
# alcohol
# men
# motorcycle
# anything
# me
# men
# me
# He
# he
# Ram
# I
# him
# I
# man
# stick
# road
# me
# man
# him
# I
# they
# kurta
# I
# they
# he
# sloganeering
# FIR
# I
# incident
# police
# I
# what
# they
# what
# they
# I
# Police
# allegations

# %%
mytext_11 = "He is booking a car"
doc_11 = nlp(mytext_11)

# %%
for word in doc_11.noun_chunks:
    print(word.text)
# Out:
# He
# a car

# %%
for word in doc_11.noun_chunks:
    print(word.root.text)
# Out:
# He
# car

# %% [markdown]
# ### Sentence Segmentation or Boundary Detection
# + Deciding where sentences begin and end
# + ===================================================
# + a) If it's a period, it ends a sentence.
# + (b) If the preceding token is in the hand-compiled list of abbreviations, then it doesn't end a sentence.
# + (c) If the next token is capitalized, then it ends a sentence.
# + ===================================================
# + Default = Uses the Dependency parser
# + Custom Rule Based or Manual
#  - - You set boundaries before parsing the doc

# %%
import spacy
nlp = spacy.load('en')

# %%
# Manual or Custom Based
def mycustom_boundary(docx):
    for words in docx[:-1]:
        if words.text == '...':
            docx[words.i+1].is_sent_start = True
    return docx

# %%
# Adding the rule before parsing
nlp.add_pipe(mycustom_boundary,before='parser')

# %%
mytext_12 = "this is my car...this is my cycle...this is my scooter...this is my house."
doc_12 = nlp(mytext_12)

# %%
for words in doc_12.sents:
    print(words)
# Out:
# this is my car...
# this is my cycle...
# this is my scooter...
# this is my house.

# %% [markdown]
# ### Custome Rule Based

# %%
from spacy.lang.en import English
from spacy.pipeline import SentenceSegmenter

# %% [markdown]
# ## Rule-based Matching
# + Tokenize
# + Pattern matching

# %%
import spacy
from spacy.matcher import Matcher 
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)

# %%
# Pattern
pattern_1 = [{"TEXT":"from"},{"ENT_TYPE" : "GPE"}]
pattern_2 = [{"TEXT":"to"},{"ENT_TYPE" : "GPE"}]
# pattern_2 = [{"dat":"DATE"}]
# Add the pattern to the matcher
matcher.add('Origin Pattern:', None,pattern_1)
matcher.add('Destination Pattern:', None,pattern_2)

# %%
text="""Dear Team,

Please book following flights 
Delhi from Lucknow on 23 sep 2019
from Lucknow to Mumbai on 25 sep 2019
from Delhi to Lucknow on 30th sep 2019

"""

# %%
doc_3= nlp(text)
type(doc_3)
matches = matcher(doc_3)

# %%
for match_id,start, end in matches:
    matched_span = doc_3[start:end]
    match_key = nlp.vocab.strings[match_id]
    print(match_key, matched_span.text)  # print("origin:",match_key, matched_span.text)
# Out:
# Origin Pattern: from Lucknow
# Origin Pattern: from Lucknow
# Destination Pattern: to Mumbai
# Origin Pattern: from Delhi
# Destination Pattern: to Lucknow

# %%
for match_id,start, end in matches:
    matched_span = doc_3[start:end]
    print(matched_span.text)
# Out:
# from Lucknow
# from Lucknow
# to Mumbai
# from Delhi
# to Lucknow

# %%
import spacy
from spacy.matcher import Matcher 
nlp = spacy.load("en_core_web_sm")
matcher = Matcher(nlp.vocab)

# Create the match patterns
pattern1 = [{"LOWER": "amazon"}, {"IS_TITLE": True, "POS": "PROPN"}]
pattern2 = [{"LOWER": "ad"}, {"TEXT": "-"}, {"LOWER": "free"}, {"POS": "NOUN"}]

# Initialize the Matcher and add the patterns
matcher = Matcher(nlp.vocab)
matcher.add("PATTERN1", None, pattern1)
matcher.add("PATTERN2", None, pattern2)

text_11 = ("Twitch Prime, the perks program for Amazon Prime members offering free "
    "loot, games and other benefits, is ditching one of its best features: "
    "ad-free viewing. According to an email sent out to Amazon Prime members "
    "today, ad-free viewing will no longer be included as a part of Twitch "
    "Prime for new members, beginning on September 14. However, members with "
    "existing annual subscriptions will be able to continue to enjoy ad-free "
    "viewing until their subscription comes up for renewal. Those with "
    "monthly subscriptions will have access to ad-free viewing until October 15.")
    
doc_11 = nlp(text_11)
matches_11 = matcher(doc_11)

for match_id,start, end in matches_11:
    matched_span = doc_11[start:end]
    match_key = nlp.vocab.strings[match_id]
    print(match_key, matched_span.text)
# Out:
# PATTERN1 Amazon Prime
# PATTERN2 ad-free viewing
# PATTERN1 Amazon Prime
# PATTERN2 ad-free viewing
# PATTERN2 ad-free viewing
# PATTERN2 ad-free viewing

# %% [markdown]
# ### Intent Classification with Rasa NLU and SpaCy
# + + A Libary for intent recognition and entity extraction based on SpaCy and Sklearn
#
# ##### NLP = NLU+NLG+ More
# + NLP = understand,process,interprete everyday human language
# + NLU = unstructured inputs and convert them into a structured form that a machine can understand and act upon
#
# #### Uses
# + Chatbot task
# + NL understanding
# + Intent classification

# %% [markdown]
# #### Installation
# + pip install rasa_nlu
# + python -m rasa_nlu.server &
# + sklearn_crfsuite
#
# #### using spacy as backend
# + pip install rasa_nlu[spacy]
# + python -m spacy download en_core_web_md
# + python -m spacy link en_core_web_md en
#
#   = = Dataset = =
# + rasa_dataset.json
# + config_spacy.yaml

# %%
# Load the Packages
from rasa_nlu.training_data  import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# %%
# Load Data 
# !cat rasa_dataset.json
# Out:
# {
#   "rasa_nlu_data": {
#     "regex_features": [
#       {
#         "name": "zipcode",
#         "pattern": "[0-9]{5}"
#       },
#       {
#         "name": "greet",
#         "pattern": "hey[^\\s]*"
#       }
#     ],
#     "entity_synonyms": [
#       {
#         "value": "chinese",
#         "synonyms": ["Chinese", "Chines", "chines"]
#       },
#       {
#         "value": "vegetarian",
#         "synonyms": ["veggie", "vegg"]
#       }
#     ],
#     "common_examples": [
#       {
#         "text": "hey",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "howdy",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "hey there",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "hello",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "hi",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "good morning",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "good evening",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "dear sir",
#         "intent": "greet",
#         "entities": []
#       },
#       {
#         "text": "yes",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "yep",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "yeah",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "indeed",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "that's right",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "ok",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "great",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "right, thank you",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "correct",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "great choice",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "sounds really good",
#         "intent": "affirm",
#         "entities": []
#       },
#       {
#         "text": "i'm looking for a place to eat",
#         "intent": "restaurant_search",
#         "entities": []
#       },
#       {
#         "text": "I want to grab lunch",
#         "intent": "restaurant_search",
#         "entities": []
#       },
#       {
#         "text": "I am searching for a dinner spot",
#         "intent": "restaurant_search",
#         "entities": []
#       },
#       {
#         "text": "i'm looking for a place in the north of town",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 31,
#             "end": 36,
#             "value": "north",
#             "entity": "location"
#           }
#         ]
#       },
#       {
#         "text": "show me chinese restaurants",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 8,
#             "end": 15,
#             "value": "chinese",
#             "entity": "cuisine"
#           }
#         ]
#       },
#       {
#         "text": "show me chines restaurants in the north",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 8,
#             "end": 14,
#             "value": "chinese",
#             "entity": "cuisine"
#           },
#           {
#             "start": 34,
#             "end": 39,
#             "value": "north",
#             "entity": "location"
#           }
#         ]
#       },
#       {
#         "text": "show me a mexican place in the centre",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 31,
#             "end": 37,
#             "value": "centre",
#             "entity": "location"
#           },
#           {
#             "start": 10,
#             "end": 17,
#             "value": "mexican",
#             "entity": "cuisine"
#           }
#         ]
#       },
#       {
#         "text": "i am looking for an indian spot called olaolaolaolaolaola",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 20,
#             "end": 26,
#             "value": "indian",
#             "entity": "cuisine"
#           }
#         ]
#       },     {
#         "text": "search for restaurants",
#         "intent": "restaurant_search",
#         "entities": []
#       },
#       {
#         "text": "anywhere in the west",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 16,
#             "end": 20,
#             "value": "west",
#             "entity": "location"
#           }
#         ]
#       },
#       {
#         "text": "anywhere near 18328",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 14,
#             "end": 19,
#             "value": "18328",
#             "entity": "location"
#           }
#         ]
#       },
#       {
#         "text": "I am looking for asian fusion food",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 17,
#             "end": 29,
#             "value": "asian fusion",
#             "entity": "cuisine"
#           }
#         ]
#       },
#       {
#         "text": "I am looking a restaurant in 29432",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 29,
#             "end": 34,
#             "value": "29432",
#             "entity": "location"
#           }
#         ]
#       },
#       {
#         "text": "I am looking for mexican indian fusion",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 17,
#             "end": 38,
#             "value": "mexican indian fusion",
#             "entity": "cuisine"
#           }
#         ]
#       },
#       {
#         "text": "central indian restaurant",
#         "intent": "restaurant_search",
#         "entities": [
#           {
#             "start": 0,
#             "end": 7,
#             "value": "central",
#             "entity": "location"
#           },
#           {
#             "start": 8,
#             "end": 14,
#             "value": "indian",
#             "entity": "cuisine"
#           }
#         ]
#       },
#       {
#         "text": "bye",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "goodbye",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "good bye",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "stop",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "end",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "farewell",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "Bye bye",
#         "intent": "goodbye",
#         "entities": []
#       },
#       {
#         "text": "have a good one",
#         "intent": "goodbye",
#         "entities": []
#       }
#     ]
#   }
# }

# %%
# Loading DataSet
train_data = load_data('rasa_dataset.json')

# %%
# Config Backend using Sklearn and Spacy
trainer = Trainer(config.load("config_spacy.yaml"))

# %%
# Training Data
trainer.train(train_data)
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.0s finished

# %%
# Returns the directory the model is stored in (Creat a folder to store model in)
model_directory = trainer.persist('/home/v-rishabh.gupta/Rishabh Gupta/Spacy')

# %% [markdown]
# #### Entity Extraction With SpaCy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
docx = nlp("I am looking for an Italian Restaurant where I can eat")

# %%
for word in docx.ents:
    print("value",word.text,"entity",word.label_,"start",word.start_char,"end",word.end_char)
# Out:
# value Italian entity NORP start 20 end 27

# %% [markdown]
# #### Making Predictions With Model
# + Interpreter.load().parse()

# %%
from rasa_nlu.model import Metadata, Interpreter

# %%
# where `model_directory points to the folder the model is persisted in
interpreter = Interpreter.load(model_directory)

# %%
# Prediction of Intent
interpreter.parse("I am looking for an Italian Restaurant where I can eat")
# Out:
# {'intent': {'name': 'restaurant_search', 'confidence': 0.7944485139668067},
#  'entities': [],
#  'intent_ranking': [{'name': 'restaurant_search',
#    'confidence': 0.7944485139668067},
#   {'name': 'goodbye', 'confidence': 0.08877027501250095},
#   {'name': 'affirm', 'confidence': 0.060768740161448884},
#   {'name': 'greet', 'confidence': 0.05601247085924364}],
#  'text': 'I am looking for an Italian Restaurant where I can eat'}

# %%
interpreter.parse("I want an African Spot to eat")
# Out:
# {'intent': {'name': 'restaurant_search', 'confidence': 0.7515793347258917},
#  'entities': [],
#  'intent_ranking': [{'name': 'restaurant_search',
#    'confidence': 0.7515793347258917},
#   {'name': 'goodbye', 'confidence': 0.14514133959768408},
#   {'name': 'affirm', 'confidence': 0.05825528337789052},
#   {'name': 'greet', 'confidence': 0.04502404229853378}],
#  'text': 'I want an African Spot to eat'}

# %%
interpreter.parse("I want to eat")
# Out:
# {'intent': {'name': 'restaurant_search', 'confidence': 0.7873296352246548},
#  'entities': [],
#  'intent_ranking': [{'name': 'restaurant_search',
#    'confidence': 0.7873296352246548},
#   {'name': 'goodbye', 'confidence': 0.10059617527557173},
#   {'name': 'affirm', 'confidence': 0.06445037511409407},
#   {'name': 'greet', 'confidence': 0.047623814385679496}],
#  'text': 'I want to eat'}

# %%
interpreter.parse("Good morning World")
# Out:
# {'intent': {'name': 'greet', 'confidence': 0.5152049261319057},
#  'entities': [],
#  'intent_ranking': [{'name': 'greet', 'confidence': 0.5152049261319057},
#   {'name': 'goodbye', 'confidence': 0.20754915133493126},
#   {'name': 'affirm', 'confidence': 0.15793542577498568},
#   {'name': 'restaurant_search', 'confidence': 0.11931049675817744}],
#  'text': 'Good morning World'}

# %% [markdown]
# ### Text Classification With Machine Learning and SpaCy
# + Text categorization / text classification is the task of assigning predefined categories to documents.
# + Sentiment Analysis
# + Multilabel classification
# + + DataSet source http://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences
#
# ##### Aim is to classify reviews into positive or negative review

# %%
# Load EDA packages
import pandas as pd

# %%
# Load our dataset
df_yelp = pd.read_table('yelp_labelled.txt')
df_imdb = pd.read_table('imdb_labelled.txt')
df_amz = pd.read_table('amazon_cells_labelled.txt')
# Out:
# /home/v-rishabh.gupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#
# /home/v-rishabh.gupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/v-rishabh.gupta/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   after removing the cwd from sys.path.

# %%
df_imdb.head()
# Out:
#   A very, very, very slow-moving, aimless movie about a distressed, drifting young man.    \
# 0  Not sure who was more lost - the flat characte...
# 1  Attempting artiness with black & white and cle...
# 2       Very little music or anything to speak of.
# 3  The best scene in the movie was when Gerardo i...
# 4  The rest of the movie lacks art, charm, meanin...
#
#    0
# 0  0
# 1  0
# 2  0
# 3  1
# 4  0

# %%
# Concatenate our Datasets
frames = [df_yelp,df_imdb,df_amz]

# %%
print(frames)
# Out:
# [                              Wow... Loved this place.  1
# 0                                   Crust is not good.  0
# 1            Not tasty and the texture was just nasty.  0
# 2    Stopped by during the late May bank holiday of...  1
# 3    The selection on the menu was great and so wer...  1
# 4       Now I am getting angry and I want my damn pho.  0
# 5                Honeslty it didn't taste THAT fresh.)  0
# 6    The potatoes were like rubber and you could te...  0
# 7                            The fries were great too.  1
# 8                                       A great touch.  1
# 9                             Service was very prompt.  1
# 10                                  Would not go back.  0
# 11   The cashier had no care what so ever on what I...  0
# 12   I tried the Cape Cod ravoli, chicken,with cran...  1
# 13   I was disgusted because I was pretty sure that...  0
# 14   I was shocked because no signs indicate cash o...  0
# 15                                 Highly recommended.  1
# 16              Waitress was a little slow in service.  0
# 17   This place is not worth your time, let alone V...  0
# 18                                did not like at all.  0
# 19                                 The Burrittos Blah!  0
# 20                                  The food, amazing.  1
# 21                               Service is also cute.  1
# 22   I could care less... The interior is just beau...  1
# 23                                  So they performed.  1
# 24   That's right....the red velvet cake.....ohhh t...  1
# 25          - They never brought a salad we asked for.  0
# 26   This hole in the wall has great Mexican street...  1
# 27   Took an hour to get our food only 4 tables in ...  0
# 28                   The worst was the salmon sashimi.  0
# 29   Also there are combos like a burger, fries, an...  1
# ..                                                 ... ..
# 969  I immediately said I wanted to talk to the man...  0
# 970                    The ambiance isn't much better.  0
# 971  Unfortunately, it only set us up for disapppoi...  0
# 972                              The food wasn't good.  0
# 973  Your servers suck, wait, correction, our serve...  0
# 974      What happened next was pretty....off putting.  0
# 975  too bad cause I know it's family owned, I real...  0
# 976               Overpriced for what you are getting.  0
# 977               I vomited in the bathroom mid lunch.  0
# 978  I kept looking at the time and it had soon bec...  0
# 979  I have been to very few places to eat that und...  0
# 980  We started with the tuna sashimi which was bro...  0
# 981                            Food was below average.  0
# 982  It sure does beat the nachos at the movies but...  0
# 983       All in all, Ha Long Bay was a bit of a flop.  0
# 984  The problem I have is that they charge $11.99 ...  0
# 985  Shrimp- When I unwrapped it (I live only 1/2 a...  0
# 986     It lacked flavor, seemed undercooked, and dry.  0
# 987  It really is impressive that the place hasn't ...  0
# 988  I would avoid this place if you are staying in...  0
# 989  The refried beans that came with my meal were ...  0
# 990         Spend your money and time some place else.  0
# 991  A lady at the table next to us found a live gr...  0
# 992            the presentation of the food was awful.  0
# 993           I can't tell you how disappointed I was.  0
# 994  I think food should have flavor and texture an...  0
# 995                           Appetite instantly gone.  0
# 996  Overall I was not impressed and would not go b...  0
# 997  The whole experience was underwhelming, and I ...  0
# 998  Then, as if I hadn't wasted enough of my life ...  0
#
# [999 rows x 2 columns],     A very, very, very slow-moving, aimless movie about a distressed, drifting young man.    \
# 0    Not sure who was more lost - the flat characte...
# 1    Attempting artiness with black & white and cle...
# 2         Very little music or anything to speak of.
# 3    The best scene in the movie was when Gerardo i...
# 4    The rest of the movie lacks art, charm, meanin...
# 5                                  Wasted two hours.
# 6    Saw the movie today and thought it was a good ...
# 7                                 A bit predictable.
# 8    Loved the casting of Jimmy Buffet as the scien...
# 9                 And those baby owls were adorable.
# 10   The movie showed a lot of Florida at it's best...
# 11   The Songs Were The Best And The Muppets Were S...
# 12                                   It Was So Cool.
# 13   This is a very "right on case" movie that deli...
# 14   It had some average acting from the main perso...
# 15   This review is long overdue, since I consider ...
# 16   I'll put this gem up against any movie in term...
# 17   It's practically perfect in all of them  a tr...
# 18    The structure of this film is easily the most...
# 19   This if the first movie I've given a 10 to in ...
# 20   If there was ever a movie that needed word-of-...
# 21   Overall, the film is interesting and thought-p...
# 22   Plus, it was well-paced and suited its relativ...
# 23                             Give this one a look.
# 24                                    I gave it a 10
# 25   The Wind and the Lion is well written and supe...
# 26                             It is a true classic.
# 27   It actually turned out to be pretty decent as ...
# 28                    Definitely worth checking out.
# 29                       The problem was the script.
# ..                                                 ...
# 717  Enough can not be said of the remarkable anima...
# 718  The art style has the appearance of crayon/pen...
# 719  If you act in such a film, you should be glad ...
# 720  This one wants to surf on the small wave of sp...
# 721  If you haven't choked in your own vomit by the...
# 722  Still, it makes up for all of this with a supe...
# 723  Just consider the excellent story, solid actin...
# 724  Instead, we got a bore fest about a whiny, spo...
# 725  Then I watched it again two Sundays ago (March...
# 726       It is a very well acted and done TV Movie.
# 727  Judith Light is one of my favorite actresses a...
# 728                I keep watching it over and over.
# 729                 It's a sad movie, but very good.
# 730  If you have not seen this movie, I definitely ...
# 731           She is as lovely as usual, this cutie!
# 732  Still it's quite interesting and entertaining ...
# 733                    ;) Recommend with confidence!
# 734  This movie is well-balanced with comedy and dr...
# 735  It was a riot to see Hugo Weaving play a sex-o...
# 736  :) Anyway, the plot flowed smoothly and the ma...
# 737  The opening sequence of this gem is a classic,...
# 738             Fans of the genre will be in heaven.
# 739                Lange had become a great actress.
# 740                It looked like a wonderful story.
# 741            I never walked out of a movie faster.
# 742  I just got bored watching Jessice Lange take h...
# 743  Unfortunately, any virtue in this film's produ...
# 744                   In a word, it is embarrassing.
# 745                               Exceptionally bad!
# 746  All in all its an insult to one's intelligence...
#
#      0
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    1
# 9    1
# 10   1
# 11   1
# 12   1
# 13   1
# 14   0
# 15   1
# 16   1
# 17   1
# 18   0
# 19   1
# 20   1
# 21   1
# 22   1
# 23   1
# 24   1
# 25   1
# 26   1
# 27   1
# 28   1
# 29   0
# ..  ..
# 717  1
# 718  1
# 719  0
# 720  0
# 721  0
# 722  1
# 723  1
# 724  0
# 725  1
# 726  1
# 727  1
# 728  1
# 729  1
# 730  1
# 731  1
# 732  1
# 733  1
# 734  1
# 735  1
# 736  1
# 737  1
# 738  1
# 739  1
# 740  1
# 741  0
# 742  0
# 743  0
# 744  0
# 745  0
# 746  0
#
# [747 rows x 2 columns],     So there is no way for me to plug it in here in the US unless I go by a converter.  \
# 0                          Good case, Excellent value.
# 1                               Great for the jawbone.
# 2    Tied to charger for conversations lasting more...
# 3                                    The mic is great.
# 4    I have to jiggle the plug to get it to line up...
# 5    If you have several dozen or several hundred c...
# 6          If you are Razr owner...you must have this!
# 7                  Needless to say, I wasted my money.
# 8                     What a waste of money and time!.
# 9                      And the sound quality is great.
# 10   He was very impressed when going from the orig...
# 11   If the two were seperated by a mere 5+ ft I st...
# 12                            Very good quality though
# 13   The design is very odd, as the ear "clip" is n...
# 14   Highly recommend for any one who has a blue to...
# 15                 I advise EVERYONE DO NOT BE FOOLED!
# 16                                    So Far So Good!.
# 17                                       Works great!.
# 18   It clicks into place in a way that makes you w...
# 19   I went on Motorola's website and followed all ...
# 20   I bought this to use with my Kindle Fire and a...
# 21            The commercials are the most misleading.
# 22   I have yet to run this new battery below two b...
# 23   I bought it for my mother and she had a proble...
# 24                Great Pocket PC / phone combination.
# 25   I've owned this phone for 7 months now and can...
# 26   I didn't think that the instructions provided ...
# 27   People couldnt hear me talk and I had to pull ...
# 28                                Doesn't hold charge.
# 29   This is a simple little phone to use, but the ...
# ..                                                 ...
# 969  I plugged it in only to find out not a darn th...
# 970                                 Excellent product.
# 971                        Earbud piece breaks easily.
# 972                                     Lousy product.
# 973  This phone tries very hard to do everything bu...
# 974  It is the best charger I have seen on the mark...
# 975                                  SWEETEST PHONE!!!
# 976             :-)Oh, the charger seems to work fine.
# 977  It fits so securely that the ear hook does not...
# 978                                 Not enough volume.
# 979                Echo Problem....Very unsatisfactory
# 980  you could only take 2 videos at a time and the...
# 981                            don't waste your money.
# 982  I am going to have to be the first to negative...
# 983  Adapter does not provide enough charging current.
# 984  There was so much hype over this phone that I ...
# 985  You also cannot take pictures with it in the c...
# 986                            Phone falls out easily.
# 987  It didn't work, people can not hear me when I ...
# 988  The text messaging feature is really tricky to...
# 989  I'm really disappointed all I have now is a ch...
# 990                                Painful on the ear.
# 991                   Lasted one day and then blew up.
# 992                                      disappointed.
# 993                              Kind of flops around.
# 994  The screen does get smudged easily because it ...
# 995  What a piece of junk.. I lose more calls on th...
# 996                       Item Does Not Match Picture.
# 997  The only thing that disappoint me is the infra...
# 998  You can not answer calls with the unit, never ...
#
#      0
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    1
# 7    0
# 8    0
# 9    1
# 10   1
# 11   0
# 12   1
# 13   0
# 14   1
# 15   0
# 16   1
# 17   1
# 18   0
# 19   0
# 20   1
# 21   0
# 22   1
# 23   0
# 24   1
# 25   1
# 26   0
# 27   0
# 28   0
# 29   0
# ..  ..
# 969  0
# 970  1
# 971  0
# 972  0
# 973  0
# 974  1
# 975  1
# 976  1
# 977  1
# 978  0
# 979  0
# 980  0
# 981  0
# 982  0
# 983  0
# 984  0
# 985  0
# 986  0
# 987  0
# 988  0
# 989  0
# 990  0
# 991  0
# 992  0
# 993  0
# 994  0
# 995  0
# 996  0
# 997  0
# 998  0
#
# [999 rows x 2 columns]]

# %%
# Renaming Column Headers
for colname in frames:
    colname.columns = ["Message","Target"]

# %%
# Column names
for colname in frames:
    print(colname.columns)
# Out:
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')
# Index(['Message', 'Target'], dtype='object')

# %%
# Assign a Key to Make it Easier
keys = ['Yelp','IMDB','Amazon']

# %%
# Merge or Concat our Datasets
df = pd.concat(frames,keys=keys)

# %%
print(df)
# Out:
#                                                       Message  Target
# Yelp   0                                   Crust is not good.       0
#        1            Not tasty and the texture was just nasty.       0
#        2    Stopped by during the late May bank holiday of...       1
#        3    The selection on the menu was great and so wer...       1
#        4       Now I am getting angry and I want my damn pho.       0
#        5                Honeslty it didn't taste THAT fresh.)       0
#        6    The potatoes were like rubber and you could te...       0
#        7                            The fries were great too.       1
#        8                                       A great touch.       1
#        9                             Service was very prompt.       1
#        10                                  Would not go back.       0
#        11   The cashier had no care what so ever on what I...       0
#        12   I tried the Cape Cod ravoli, chicken,with cran...       1
#        13   I was disgusted because I was pretty sure that...       0
#        14   I was shocked because no signs indicate cash o...       0
#        15                                 Highly recommended.       1
#        16              Waitress was a little slow in service.       0
#        17   This place is not worth your time, let alone V...       0
#        18                                did not like at all.       0
#        19                                 The Burrittos Blah!       0
#        20                                  The food, amazing.       1
#        21                               Service is also cute.       1
#        22   I could care less... The interior is just beau...       1
#        23                                  So they performed.       1
#        24   That's right....the red velvet cake.....ohhh t...       1
#        25          - They never brought a salad we asked for.       0
#        26   This hole in the wall has great Mexican street...       1
#        27   Took an hour to get our food only 4 tables in ...       0
#        28                   The worst was the salmon sashimi.       0
#        29   Also there are combos like a burger, fries, an...       1
# ...                                                       ...     ...
# Amazon 969  I plugged it in only to find out not a darn th...       0
#        970                                 Excellent product.       1
#        971                        Earbud piece breaks easily.       0
#        972                                     Lousy product.       0
#        973  This phone tries very hard to do everything bu...       0
#        974  It is the best charger I have seen on the mark...       1
#        975                                  SWEETEST PHONE!!!       1
#        976             :-)Oh, the charger seems to work fine.       1
#        977  It fits so securely that the ear hook does not...       1
#        978                                 Not enough volume.       0
#        979                Echo Problem....Very unsatisfactory       0
#        980  you could only take 2 videos at a time and the...       0
#        981                            don't waste your money.       0
#        982  I am going to have to be the first to negative...       0
#        983  Adapter does not provide enough charging current.       0
#        984  There was so much hype over this phone that I ...       0
#        985  You also cannot take pictures with it in the c...       0
#        986                            Phone falls out easily.       0
#        987  It didn't work, people can not hear me when I ...       0
#        988  The text messaging feature is really tricky to...       0
#        989  I'm really disappointed all I have now is a ch...       0
#        990                                Painful on the ear.       0
#        991                   Lasted one day and then blew up.       0
#        992                                      disappointed.       0
#        993                              Kind of flops around.       0
#        994  The screen does get smudged easily because it ...       0
#        995  What a piece of junk.. I lose more calls on th...       0
#        996                       Item Does Not Match Picture.       0
#        997  The only thing that disappoint me is the infra...       0
#        998  You can not answer calls with the unit, never ...       0
#
# [2745 rows x 2 columns]

# %%
# write csv
df.to_csv("sentimentdataset.csv")

# %%
df.columns
# Out:
# Index(['Message', 'Target'], dtype='object')

# %%
# Checking for Missing Values
df.isnull().sum()
# Out:
# Message    0
# Target     0
# dtype: int64

# %% [markdown]
# ###  Working with SpaCy
# + Removing Stopwords
# + Lemmatizing

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_sm')

# %%
# Build a list of stopwords to use to filter
stopwords = list(STOP_WORDS)

# %% [markdown]
# ##### Getting Lemma and Stop words

# %%
docx = nlp("This is how John Walker was walking. He was also running beside the lawn.")

# %%
# Lemmatizing of tokens
for word in docx:
    print(word.text,"Lemma =>",word.lemma_)
# Out:
# This Lemma => this
# is Lemma => be
# how Lemma => how
# John Lemma => John
# Walker Lemma => Walker
# was Lemma => be
# walking Lemma => walk
# . Lemma => .
# He Lemma => -PRON-
# was Lemma => be
# also Lemma => also
# running Lemma => run
# beside Lemma => beside
# the Lemma => the
# lawn Lemma => lawn
# . Lemma => .

# %%
# Lemma that are not pronouns
for word in docx:
    if word.lemma_ != "-PRON-":
        print(word.lemma_.lower().strip())
# Out:
# this
# be
# how
# john
# walker
# be
# walk
# .
# be
# also
# run
# beside
# the
# lawn
# .

# %%
# List Comprehensions of our Lemma
[word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in docx]
# Out:
# ['this',
#  'be',
#  'how',
#  'john',
#  'walker',
#  'be',
#  'walk',
#  '.',
#  'he',
#  'be',
#  'also',
#  'run',
#  'beside',
#  'the',
#  'lawn',
#  '.']

# %%
# Filtering out Stopwords and Punctuations
for word in docx:
    if word.is_stop == False and not word.is_punct:
#     if word.is_stop != True and not word.is_punct:
        print(word)
# Out:
# John
# Walker
# walking
# running
# lawn

# %%
# Stop words and Punctuation In List Comprehension
[ word for word in docx if word.is_stop == False and not word.is_punct ]
# Out:
# [John, Walker, walking, running, lawn]

# %%
# Use the punctuations of string module
import string
punctuations = string.punctuation

# %%
# Creating a Spacy Parser
from spacy.lang.en import English
parser = English()

# %%
def spacy_tokenizer(sentence):
    mytokens = parser(sentence)
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]
    mytokens = [ word for word in mytokens if word not in stopwords and word not in punctuations ]
    return mytokens

# %% [markdown]
# #### Machine Learning With SKlearn

# %%
# ML Packages
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.metrics import accuracy_score 
from sklearn.base import TransformerMixin 
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
